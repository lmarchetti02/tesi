# %%
import numpy as np
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %%
x, y, z = np.loadtxt("results/data.txt", dtype=np.float_, delimiter=",", unpack=True, skiprows=2)
c = x + y

# %%
# Creating figure
fig = plt.figure(figsize =(12, 12))
ax = plt.axes(projection ='3d')
 
# Creating plot
ax.plot_trisurf(x, y, z,
                linewidth = 0.2,
                antialiased = True)
