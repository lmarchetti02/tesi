# %%
import numpy as np
from scipy import interpolate 
import matplotlib.pyplot as plt
from numba import njit

# %%
@njit
def get_mid_point(arr: np.ndarray):
    res = np.empty(len(arr)-1)

    for i in range(len(arr)-1):
        res[i] = arr[i] + (arr[i+1] - arr[i])/2    
    
    return res

# %%
def distribution(x):
    return (1/np.sqrt(2))*np.exp(-x**2/2)

# %%
data = np.random.normal(0, 1, 10_000)

n, bins, patches = plt.hist(data, bins="auto",density=True, cumulative=True, histtype="stepfilled")

plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(12,6))

bins = get_mid_point(bins)

cdf = interpolate.interp1d(bins, n)
inverse_cdf = interpolate.interp1d(n, bins)

ax[0].scatter(bins, n)
ax[0].plot(bins, cdf(bins), color="firebrick")
ax[0].set_title("Cumulative Density Function")
ax[0].grid()

ax[1].scatter(n, bins)
ax[1].plot(n, inverse_cdf(n), color="firebrick")
ax[1].set_title("Inverse Cumulative Density Function")
ax[1].grid()

u = np.random.uniform(0.001, 0.999, 100)
#ax[1].plot(u, inverse_cdf(u))

plt.show()

# %%
e = 1e-4
u = np.random.uniform(e, 1-e, 10_000)
sample = inverse_cdf(u)

plt.hist(sample, bins="auto", density=True, color="firebrick", label="Sampled values")
plt.hist(data, bins="auto", density=True, color="navy", alpha=0.7, label="Original distribution")

plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 e = 1e-4
#       2 u = np.random.uniform(e, 1-e, 10_000)
# ----> 3 sample = inverse_cdf(u)
#       5 plt.hist(sample, bins="auto", density=True, color="firebrick", label="Sampled values")
#       6 plt.hist(data, bins="auto", density=True, color="navy", alpha=0.7, label="Original distribution")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/interpolate/_polyint.py:81, in _Interpolator1D.__call__(self, x)
#      60 """
#      61 Evaluate the interpolant
#      62
#    (...)
#      78
#      79 """
#      80 x, x_shape = self._prepare_x(x)
# ---> 81 y = self._evaluate(x)
#      82 return self._finish_y(y, x_shape)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:764, in interp1d._evaluate(self, x_new)
#     762 y_new = self._call(self, x_new)
#     763 if not self._extrapolate:
# --> 764     below_bounds, above_bounds = self._check_bounds(x_new)
#     765     if len(y_new) > 0:
#     766         # Note fill_value must be broadcast up to the proper size
#     767         # and flattened to work here
#     768         y_new[below_bounds] = self._fill_value_below
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:793, in interp1d._check_bounds(self, x_new)
#     791 if self.bounds_error and below_bounds.any():
#     792     below_bounds_value = x_new[np.argmax(below_bounds)]
# --> 793     raise ValueError(f"A value ({below_bounds_value}) in x_new is below "
#     794                      f"the interpolation range's minimum value ({self.x[0]}).")
#     795 if self.bounds_error and above_bounds.any():
#     796     above_bounds_value = x_new[np.argmax(above_bounds)]
#
# ValueError: A value (0.0004249980033563894) in x_new is below the interpolation range's minimum value (0.0005).
